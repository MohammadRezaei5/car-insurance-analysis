# %%
import pandas as pd

df_freq = pd.read_csv('freMTPL2freq.csv')
df_sev = pd.read_csv('freMTPL2sev.csv')

df_claims_merge = df_freq.merge(
    df_sev,
    on='IDpol',
    how='left'
)

df_claims_merge['ClaimAmount'] = df_claims_merge['ClaimAmount'].fillna(0)

# df_claims_merge.to_excel("tableau_claims.xlsx", index=False)
